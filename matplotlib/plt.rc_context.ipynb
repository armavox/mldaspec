# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.gofplots import qqplot_2samples

np.random.seed(10)
sample1 = np.random.rand(10)
sample2 = np.random.rand(10)
n, m = 6, 6

with plt.rc_context(rc={'figure.figsize': (12,4), 'figure.dpi': 100}):
    qqplot_2samples(sample1, sample2, line = 'r')

# %%
with plt.rc_context(rc={'figure.figsize': (12,4), 'figure.dpi': 300}):
    sm.graphics.tsa.plot_acf(
        milk.daily_diff12_1.dropna().values.squeeze());
