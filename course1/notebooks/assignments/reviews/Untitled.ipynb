# %% [markdown]
# **Cenral limit theorem handmade**
# ___

# %%
import numpy as np
import scipy.stats as sts
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mu = 0.25
sigma = 1
lognorm = sts.lognorm(mu, sigma)

# %%
true_mu = np.exp(mu + (sigma**2)/2)
true_sigma = (np.exp(sigma**2 - 1) * np.exp(2*mu + sigma**2)) ** (1/2)
print(true_mu)
# Out:
# 2.117000016612675

# %%
numbers = lognorm.rvs(1000)
x = np.linspace(lognorm.ppf(0.001), lognorm.ppf(0.999), 1000)

# %%
plt.style.use('classic')

# %%
plt.hist(numbers, bins=25, alpha=0.5, density=True)
plt.plot(x, lognorm.pdf(x), lw=2);

# %%
lognorm_5 = []
for i in range(100000):
    lognorm_5.append(lognorm.rvs(5).mean())

# %%
#plt.hist(lognorm_5, bins=30, alpha=0.5, density=True);
plt.plot(np.linspace(-5,8,100), sts.norm(true_mu, true_sigma).pdf(np.linspace(-5,8,100)));

# %%
np.array(lognorm_5).mean()
# Out:
# 2.0313167766007427
